# %%
import pandas as pd

# %%
# pandas has two core object series, dataframe

# %%
# series
pd.Series((1,2,2,3),name="Age")
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# Name: Age, dtype: int64

# %%
# dataframe 
# dict 
di={"Name":["anand","mango","pen","mobile"],
    "Identity":["human","fruit","object",None]
}

df=pd.DataFrame(di)

print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.head(2)
# Out:
#     Name Identity
# 0  anand    human
# 1  mango    fruit

# %%
df.tail(2)
# Out:
#      Name Identity
# 2     pen   object
# 3  mobile      NaN

# %%
df.sample()
# Out:
#     Name Identity
# 0  anand    human

# %%
df.head()
# Out:
#      Name Identity
# 0   anand    human
# 1   mango    fruit
# 2     pen   object
# 3  mobile      NaN

# %%
type(df["Name"])
# Out:
# pandas.Series

# %%
df[["Name","Identity"]]
# Out:
#      Name Identity
# 0   anand    human
# 1   mango    fruit
# 2     pen   object
# 3  mobile      NaN

# %%
df = df.drop(columns=["count"])

count = [1, 10, 3, 2]
df.insert(0, "count", count)

print(df)
# Out:
#    count    Name Identity
# 0      1   anand    human
# 1     10   mango    fruit
# 2      3     pen   object
# 3      2  mobile      NaN

# %%
colour = "skin","orange","blue","black"

# %%
df["color"] =colour

# %%
df["id"] =[1,2,3,4]

# %%
df.sample()
# Out:
#    count Name Identity color  id
# 2      3  pen   object  blue   3

# %%
df2 = pd.DataFrame({
    'id': [1, 2, 6, 4,5],
    'weight': [55, 62, 48, 70,None]
})

print(df2)
# Out:
#    id  weight
# 0   1    55.0
# 1   2    62.0
# 2   6    48.0
# 3   4    70.0
# 4   5     NaN

# %%
# merge or join
pd.merge(df,df2, how="left",on="id")
# Out:
#    count    Name Identity   color  id  weight
# 0      1   anand    human    skin   1    55.0
# 1     10   mango    fruit  orange   2    62.0
# 2      3     pen   object    blue   3     NaN
# 3      2  mobile      NaN   black   4    70.0

# %%
pd.merge(df,df2)  # sets
# Out:
#    count    Name Identity   color  id  weight
# 0      1   anand    human    skin   1    55.0
# 1     10   mango    fruit  orange   2    62.0
# 2      2  mobile      NaN   black   4    70.0
